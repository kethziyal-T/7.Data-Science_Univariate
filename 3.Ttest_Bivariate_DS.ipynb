# %%
import pandas as pd

# %%
dataset=pd.read_csv("PrePlacement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dir(dataset)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
dataset.cov(numeric_only=True)
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3870.000000     -52.641355     -58.106028     -40.413645
# ssc_p       -52.641355     117.228377      60.348373      42.897137
# hsc_p       -58.106028      60.348373     118.755706      34.819820
# degree_p    -40.413645      42.897137      34.819820      54.151103
# etest_p      52.556168      37.659225      35.461678      21.929469
# mba_p         8.102336      24.535952      22.555846      17.272020
# salary    24490.654206  901754.893936  763359.777657  465131.504238
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336  2.449065e+04
# ssc_p         37.659225      24.535952  9.017549e+05
# hsc_p         35.461678      22.555846  7.633598e+05
# degree_p      21.929469      17.272020  4.651315e+05
# etest_p      176.251018      16.886973  3.842344e+05
# mba_p         16.886973      34.028376  1.262455e+05
# ...

# %%
# covariance between degree and e_test is positive covariance 21.9 =22
# covariance between e_test and mba is positive covariance 16.88 =17

# %%
dataset.corr(numeric_only=True)
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
# correlation between mba and salary is positive correlation 0.139 =14

# %%
dataset.drop(['sl_no'],inplace=True,axis=1)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
import seaborn as sns
# Out:
# /home/kethziyal19/.local/lib/python3.11/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
sns.pairplot(dataset)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def cal_vif(X):
    
    #calcularting vif
    vif=pd.DataFrame()
    vif["variables"]=X.columns
    vif["VIF"]=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
    return(vif)

# %% [markdown]
# # 1.Drop Features: To check vif:

# %%
cal_vif(dataset[['etest_p','salary']])
# Out:
#   variables       VIF
# 0   etest_p  2.745261
# 1    salary  2.745261

# %% [markdown]
# # 2.select only numerical features(excluding target variables)

# %%
# Check only your clean independent predictor variables

final_features = dataset[['hsc_p', 'degree_p', 'etest_p', 'mba_p']]

cal_vif(final_features)
# Out:
#   variables        VIF
# 0     hsc_p  50.423078
# 1  degree_p  98.304027
# 2   etest_p  32.366218
# 3     mba_p  97.255096

# %% [markdown]
# # 3.Combine Features:To check vif:

# %%
# Create a new column that is the average of both school scores
dataset['school_perf_avg'] = (dataset['ssc_p'] + dataset['hsc_p']) / 2

# Drop the original individual columns to remove the collinearity
dataset = dataset.drop(columns=['ssc_p', 'hsc_p'])

# %%
dataset
# Out:
#     gender    ssc_b    hsc_b     hsc_s  degree_p   degree_t workex  etest_p  \
# 0        M   Others   Others  Commerce     58.00   Sci&Tech     No     55.0
# 1        M  Central   Others   Science     77.48   Sci&Tech    Yes     86.5
# 2        M  Central  Central      Arts     64.00  Comm&Mgmt     No     75.0
# 3        M  Central  Central   Science     52.00   Sci&Tech     No     66.0
# 4        M  Central  Central  Commerce     73.30  Comm&Mgmt     No     96.8
# ..     ...      ...      ...       ...       ...        ...    ...      ...
# 210      M   Others   Others  Commerce     77.60  Comm&Mgmt     No     91.0
# 211      M   Others   Others   Science     72.00   Sci&Tech     No     74.0
# 212      M   Others   Others  Commerce     73.00  Comm&Mgmt    Yes     59.0
# 213      F   Others   Others  Commerce     58.00  Comm&Mgmt     No     70.0
# 214      M  Central   Others   Science     53.00  Comm&Mgmt     No     89.0
#
# ...

# %%
cal_vif(dataset[['mba_p','salary']])
# Out:
#   variables       VIF
# 0     mba_p  2.707661
# 1    salary  2.707661

# %%
# Create a new column that is the average of both degree scores
dataset['degree_perf_avg'] = (dataset['degree_p'] + dataset['mba_p']) / 2

# Drop the original individual columns to remove the collinearity
dataset = dataset.drop(columns=['degree_p', 'mba_p'])

# %%
cal_vif(dataset[['etest_p','salary']])
# Out:
#   variables       VIF
# 0   etest_p  2.745261
# 1    salary  2.745261

# %%
dataset
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex  etest_p  \
# 0        M   Others   Others  Commerce   Sci&Tech     No     55.0
# 1        M  Central   Others   Science   Sci&Tech    Yes     86.5
# 2        M  Central  Central      Arts  Comm&Mgmt     No     75.0
# 3        M  Central  Central   Science   Sci&Tech     No     66.0
# 4        M  Central  Central  Commerce  Comm&Mgmt     No     96.8
# ..     ...      ...      ...       ...        ...    ...      ...
# 210      M   Others   Others  Commerce  Comm&Mgmt     No     91.0
# 211      M   Others   Others   Science   Sci&Tech     No     74.0
# 212      M   Others   Others  Commerce  Comm&Mgmt    Yes     59.0
# 213      F   Others   Others  Commerce  Comm&Mgmt     No     70.0
# 214      M  Central   Others   Science  Comm&Mgmt     No     89.0
#
#     specialisation      status    salary  school_perf_avg  degree_perf_avg
# 0           Mkt&HR      Placed  270000.0            79.00           58.400
# ...

# %% [markdown]
# # 4.Feature Extraction: Principal Component Analysis (PCA)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# 1. Isolate the two highly correlated school performance columns
school_features = dataset[['ssc_p', 'hsc_p']]

# 2. Scale the features (PCA requires standardized data)
scaler = StandardScaler()
scaled_school = scaler.fit_transform(school_features)

# 3. Apply PCA to reduce the 2 columns down to 1 component
pca = PCA(n_components=1)
school_pca_component = pca.fit_transform(scaled_school)

# 4. Add the new PCA feature back into your main dataset
dataset['school_performance_pca'] = school_pca_component

# 5. Drop the old, highly correlated columns to eliminate multicollinearity
dataset_clean = dataset.drop(columns=['ssc_p', 'hsc_p'])

# 6. Check the variance retained (Optional but recommended)
explained_variance = pca.explained_variance_ratio_[0] * 100
print(f"The new PCA feature retains {explained_variance:.2f}% of the original information.")
# Out:
# The new PCA feature retains 75.57% of the original information.

# %%
cal_vif(dataset[['etest_p','salary']])
# Out:
#   variables       VIF
# 0   etest_p  2.745261
# 1    salary  2.745261

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %%
dataset.drop('sl_no',inplace=True,axis=1)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary  \
# ...

# %% [markdown]
# # homoscedasticity:

# %%
X= dataset[["etest_p"]]
y=dataset["salary"]

# %%
import statsmodels.api as sm
X_constant=sm.add_constant(X)
model=sm.OLS(y,X_constant).fit()

# %%
import matplotlib.pyplot as plt
residuals=model.resid
fitted_values=model.fittedvalues
plt.scatter(fitted_values,residuals,alpha=0.6,edgecolors='k')
plt.axhline(y=0,color='red',linestyle='--',linewidth=1.5)
plt.xlabel('Fitted Values(Predicted package )')
plt.ylabel('Residuals(Errors)')
plt.title('Homoscedasticity check on placement dataset')
plt.show()

# %%
# Statistical check (Breusch_Pagan Test)
from statsmodels.stats.diagnostic import het_breuschpagan
bp_test=het_breuschpagan(residuals,X_constant)
labels=['Lagrange Multipplier Statistic','LM p_value','F_Statistic','F p_value',]
print("Breusch_Pagan Test Results")
for label,value in zip(labels,bp_test):
    print(f"{label}:{value:4f}")
# Out:
# Breusch_Pagan Test Results
# Lagrange Multipplier Statistic:0.270045
# LM p_value:0.603301
# F_Statistic:0.267870
# F p_value:0.605302

# %%
import statsmodels.api as sm

# Instead of just .fit(), use a robust covariance type
model = sm.OLS(y, X).fit(cov_type='HC3')
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared (uncentered):                   0.636
# Model:                            OLS   Adj. R-squared (uncentered):              0.634
# Method:                 Least Squares   F-statistic:                              364.2
# Date:                Thu, 11 Jun 2026   Prob (F-statistic):                    4.46e-48
# Time:                        11:31:25   Log-Likelihood:                         -2870.2
# No. Observations:                 215   AIC:                                      5742.
# Df Residuals:                     214   BIC:                                      5746.
# Df Model:                           1
# Covariance Type:                  HC3
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import statsmodels.api as sm

# Apply log transformation to the target variable
y_log = np.log1p(y)  # log1p handles zeroes safely if any exist

# Re-run your OLS model
log_model = sm.OLS(y_log, X).fit()

# %%
# result hetroscedasticity because p-value is >0.5

# %% [markdown]
# # T_test

# %% [markdown]
# # independent sample-Unpaired ttest:

# %%
#different gruops(male,female) with same consition(salary)

# %%
dataset[dataset['gender']=='M']['salary']
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3           0.0
# 4      425000.0
#          ...
# 209    216000.0
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 214         0.0
# Name: salary, Length: 139, dtype: float64

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
male=dataset[dataset['gender']=='M']['salary']
female=dataset[dataset['gender']=='F']['salary']

#print("male")
ttest_ind(male,female)
# Out:
# TtestResult(statistic=np.float64(2.1103433958668765), pvalue=np.float64(0.03599560646745178), df=np.float64(213.0))

# %% [markdown]
# # dependent sample - Paired ttest:
#
# Same group(male) but Different (ssc_p,hsc_p)

# %%
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
male=dataset[dataset['gender']=='M']['ssc_p']
male1=dataset[dataset['gender']=='M']['hsc_p']

#print("male")
ttest_rel(male,male1)
# Out:
# TtestResult(statistic=np.float64(0.6852881050898076), pvalue=np.float64(0.49431164600731514), df=np.int64(138))

# %%
# large different = 0.6852881050898076  less similarity ; pvalue=0.49431164600731514 above 5% so less significant

# %% [markdown]
# # case1:
# same group(Male);Different Condition(ssc_p,hsc_p) - Paired & dependent sample

# %%
from scipy.stats import ttest_rel
dataset=dataset.dropna()
hsc_s=dataset[dataset['hsc_s']=='Commerce']['mba_p']
hsc_s1=dataset[dataset['hsc_s']=='Commerce']['etest_p']

#print("male")
ttest_rel(hsc_s,hsc_s1)
# Out:
# TtestResult(statistic=np.float64(-7.868552092606871), pvalue=np.float64(2.462926468454984e-12), df=np.int64(112))

# %%
# smaller different = -7.868552092606871  more similarity ; pvalue=2.462926468454984e above 5% so less significant

# %% [markdown]
# # Case2:
# Different group(others,Central) ; Same condition(Salary) - Unpaired - Independent sample

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
hsc_b=dataset[dataset['hsc_b']=='Others']['salary']
hsc_b1=dataset[dataset['hsc_b']=='Central']['salary']

#print("male")
ttest_ind(hsc_b,hsc_b1)
# Out:
# TtestResult(statistic=np.float64(0.1684880697892395), pvalue=np.float64(0.8663592108619098), df=np.float64(213.0))

# %%
# Smaller different = 0.1684880697892395  more similarity ; pvalue= 0.8663592108619098 above 5% so less significant

# %% [markdown]
# # Case 3:
# Different Groups(Commerce,Science) ; Same Condition(mba_p) - Unpaired - Independent Sample

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
hsc_s=dataset[dataset['hsc_s']=='Commerce']['mba_p']
hsc_s1=dataset[dataset['hsc_s']=='Science']['mba_p']

#print("male")
ttest_ind(hsc_s,hsc_s1)
# Out:
# TtestResult(statistic=np.float64(-0.7331285580404581), pvalue=np.float64(0.46432995253854314), df=np.float64(202.0))

# %%
# Smaller different = -0.7331285580404581  more similarity ; pvalue= 0.46432995253854314 above 5% so less significant
